# %% [markdown]
# Different limits, logging PNL:
#
# Michael's dynamic thing:
# Profit summary:
# Round 1 day -2: 2,326
# Round 1 day -1: 4,321
# Round 1 day 0: 538
# Round 2 day -1: 4,321
# Round 2 day 0: 538
# Round 2 day 1: 2,975
# Round 3 day 0: 538
# Round 3 day 1: 2,975
# Round 3 day 2: 4,481
# Round 4 day 1: 2,975
# Round 4 day 2: 4,481
# Round 4 day 3: 464
# Total profit: 30,933
#
# 20:
# Profit summary:
# Round 1 day -2: 1,691
# Round 1 day -1: 5,210
# Round 1 day 0: 1,195
# Round 2 day -1: 5,210
# Round 2 day 0: 1,195
# Round 2 day 1: 2,061
# Round 3 day 0: 1,195
# Round 3 day 1: 2,061
# Round 3 day 2: 5,500
# Round 4 day 1: 2,061
# Round 4 day 2: 5,500
# Round 4 day 3: 389
# Total profit: 33,268
#
# 30:
# Profit summary:
# Round 1 day -2: 2,263
# Round 1 day -1: 5,012
# Round 1 day 0: 1,123
# Round 2 day -1: 5,012
# Round 2 day 0: 1,123
# Round 2 day 1: 2,935
# Round 3 day 0: 1,123
# Round 3 day 1: 2,935
# Round 3 day 2: 6,072
# Round 4 day 1: 2,935
# Round 4 day 2: 6,072
# Round 4 day 3: 289
# Total profit: 36,894
#
# 40:
# Profit summary:
# Round 1 day -2: 2,444
# Round 1 day -1: 5,012
# Round 1 day 0: 1,123
# Round 2 day -1: 5,012
# Round 2 day 0: 1,123
# Round 2 day 1: 2,926
# Round 3 day 0: 1,123
# Round 3 day 1: 2,926
# Round 3 day 2: 5,791
# Round 4 day 1: 2,926
# Round 4 day 2: 5,791
# Round 4 day 3: 289
# Total profit: 36,486

# %% [markdown]
# I need to grid search over various permutations.
#
# SMA, WMA, VWMA, and EMA.
#
# Different windows. 1-1000 width timestamps.
#
# I'm gonna take this offline.
